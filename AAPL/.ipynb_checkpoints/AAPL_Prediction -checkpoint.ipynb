# %%
# Imports
import yfinance as yf
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
# Loading model
loaded_model = tf.keras.models.load_model('AAPL_model.h5')
print(loaded_model.summary())

# Importing data from 2022-01-14 to 2022-02-14
oneStockAAPL = yf.Ticker("AAPL").history(start="2022-01-15", end="2022-02-15")
oneStockAAPL.insert(0, 'Timestamp', oneStockAAPL.index)
oneStockAAPL.reset_index(drop=True, inplace=True)
oneStockAAPL
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 60, 50)            10400
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 50)            0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60, 50)            20200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 50)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# ...

# %%
#print(loaded_model.predict(X_train))
# Preping the data
# Scaler
sc = MinMaxScaler(feature_range=(0, 1))
scaled_data  = sc.fit_transform(closing_price.reshape(-1,1))

# Train scaling
training_data = scaled_data[0:split, :]

for i in range(60, len(training_data)):
    X_train.append(training_data[i-60:i, 0])
    y_train.append(training_data[i, 0])
       
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
print(X_train.shape)
